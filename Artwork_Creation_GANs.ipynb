# %%
# %load_ext nb_black

# %%
# Import packages here
import pandas as pd
import numpy as np
import glob
from PIL import Image
from matplotlib import pyplot as plt

# %% [markdown]
# # Read in Data
# - Abstract images
# - Determine what dimension our images should be -- this is highly dependent on the GAN model input dimensions

# %%
filelist_train = glob.glob("data/train/abstract/*.jpg")
filelist_test = glob.glob("data/test/abstract/*.jpg")

# %%
x_input_train = np.array([np.array(Image.open(fname)) for fname in filelist_train])
x_input_test = np.array([np.array(Image.open(fname)) for fname in filelist_test])

# %%
plt.imshow(x_input_train[0], interpolation="nearest")  # taking a look at an image.
plt.show()

# %%
x_input_train[
    0
].shape  # (299, 299, 3) --> We might need to resize these images depending on a GAN input.
# Out:
# (299, 299, 3)

# %% [markdown]
# # Utilize Transfer Learning
# - GAN networks
# - Load in pre-trained network and only train last 1 or 2 layers with abstract data.

# %% [markdown]
# # Saving the Model weights
# - model_weights/model.h5
